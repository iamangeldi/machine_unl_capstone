# %% [markdown]
# # Metric Notebook: Recovery Attacks on Diffusion Models

# %% [markdown]
# Required libraries

# %%
import os
import json
import math
from pathlib import Path
from typing import List, Dict, Tuple

import torch
import numpy as np
from PIL import Image

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

from diffusers import StableDiffusionXLPipeline, AutoencoderKL
from transformers import CLIPProcessor, CLIPModel

# %%
import os
os.environ["HF_TOKEN"] = "ADD YOUR OWN TOKEN"

assert os.environ["HF_TOKEN"] != "ADD YOUR OWN TOKEN", "Please set HF_TOKEN environment variable"

# %% [markdown]
# ### Image Generation (Baseline)
# Generates a fixed grid of images (same prompts + seeds) from three SDXL variants (base, original LoRA, recreated LoRA), saves them to `./clip_style_eval_outputs/generated`, and writes a `gen_records.json` manifest with metadata + file paths for downstream metrics.

# %%
OUT_ROOT = Path("./clip_style_eval_outputs")
GEN_DIR  = OUT_ROOT / "generated"
META_PATH = OUT_ROOT / "gen_records.json"
OUT_ROOT.mkdir(parents=True, exist_ok=True)

positive_prompt_set = [
    "a tattoo in the style of JASON, a roaring tiger, bold black ink, yellow highlights, clean linework, high contrast",
    "a tattoo in the style of JASON, a dagger wrapped in roses, bold black ink, yellow highlights, sharp outlines, flat shading",
    "a tattoo in the style of JASON, a mechanical owl with spread wings, bold black ink, yellow highlights, strong outlines, graphic style",
]
negative_prompt_set = [
    "a roaring tiger, realistic wildlife photograph, natural lighting, DSLR photo",
    "a dagger wrapped in roses, watercolor illustration, soft edges, pastel colors",
    "a mechanical owl with spread wings, 3D render, cinematic lighting, ultra detailed",
]
seed_set = [1234, 667, 3067]

GEN_CFG = dict(num_inference_steps=30, guidance_scale=7.0)

# ------------------ DEVICE ------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
dtype  = torch.float16 if device == "cuda" else torch.float32

# ------------------ LOAD VAE ------------------
vae = AutoencoderKL.from_pretrained(
    "madebyollin/sdxl-vae-fp16-fix",
    torch_dtype=dtype
)

# ------------------ LOAD PIPES ------------------
def load_pipe(repo_id: str) -> StableDiffusionXLPipeline:
    common = dict(vae=vae, torch_dtype=dtype, use_safetensors=True)

    # Don't assume fp16 variant exists for all repos
    if dtype == torch.float16:
        try:
            pipe = StableDiffusionXLPipeline.from_pretrained(repo_id, variant="fp16", **common).to(device)
        except ValueError as e:
            if "variant=fp16" not in str(e):
                raise
            pipe = StableDiffusionXLPipeline.from_pretrained(repo_id, **common).to(device)
    else:
        pipe = StableDiffusionXLPipeline.from_pretrained(repo_id, **common).to(device)

    pipe.set_progress_bar_config(disable=True)
    return pipe

pipes = {
    "base": load_pipe("stabilityai/stable-diffusion-xl-base-1.0"),
    "original": load_pipe("francuzama/sdxl-fused"),
    "recreated": load_pipe("francuzama/sdxl-recovered"),
}

@torch.inference_mode()
def generate_one(pipe: StableDiffusionXLPipeline, prompt: str, seed: int) -> Image.Image:
    g = torch.Generator(device=device).manual_seed(int(seed))
    out = pipe(prompt=prompt, generator=g, **GEN_CFG)
    return out.images[0]

def generate_all_images(
    pipes: Dict[str, StableDiffusionXLPipeline],
    pos_prompts: List[str],
    neg_prompts: List[str],
    seeds: List[int],
    out_dir: Path
) -> List[Dict]:
    out_dir.mkdir(parents=True, exist_ok=True)
    records: List[Dict] = []

    for model_name, pipe in pipes.items():
        for polarity, prompt_set in [("pos", pos_prompts), ("neg", neg_prompts)]:
            for prompt_id, prompt in enumerate(prompt_set):
                for seed in seeds:
                    img = generate_one(pipe, prompt, seed)
                    fname = f"{model_name}__{polarity}__p{prompt_id:02d}__s{seed}.png"
                    fpath = out_dir / fname
                    img.save(fpath)

                    records.append({
                        "model": model_name,
                        "polarity": polarity,
                        "prompt_id": prompt_id,
                        "seed": seed,
                        "prompt": prompt,
                        "path": str(fpath),
                    })
                    print("[saved]", fpath)

    return records

gen_records = generate_all_images(
    pipes=pipes,
    pos_prompts=positive_prompt_set,
    neg_prompts=negative_prompt_set,
    seeds=seed_set,
    out_dir=GEN_DIR,
)

with open(META_PATH, "w") as f:
    json.dump(gen_records, f, indent=2)

print(f"\nGenerated {len(gen_records)} images → {GEN_DIR.resolve()}")
print(f"Saved manifest → {META_PATH.resolve()}")

# %% [markdown]
# ## Metric #1 — CLIP Style Similarity (to Held-Out Tattoo References)
#
# **Goal:** Quantify how “tattoo-style” generated outputs are by measuring their proximity to unseen tattoo references in CLIP embedding space.
#
# ### Setup
# - Fixed prompt set:
#   - **Positive prompts** (intended to trigger tattoo style)
#   - **Negative prompts** (intended to avoid tattoo style)
# - Fixed random seeds
# - Fixed generation parameters (steps, guidance scale, resolution, sampler)
# - Models compared:
#   - Base
#   - Original LoRA (fused)
#   - Recreated LoRA (fused)
# - Held-out tattoo reference dataset (not used during training)
#
# ### Computation
# 1. Generate images for each model using identical prompts and seeds.
# 2. Compute CLIP image embeddings for:
#    - All generated images
#    - All held-out reference images
# 3. For each generated image:
#    - Compute cosine similarity to reference embeddings
#    - Use **top-k mean similarity** (k = 5)
# 4. Aggregate results:
#    - Mean ± standard deviation (overall)
#    - Mean ± standard deviation (positive prompts)
#    - Mean ± standard deviation (negative prompts)
#
#
# ### Interpretation
# - On **positive prompts**, Original and Recreated should score higher than Base.
# - On **negative prompts**, similarity should remain lower (style control).
# - Recovery ≈ 1.0 indicates successful reconstruction of stylistic behavior.
#
# ### What This Shows
# A bar plot of CLIP similarity (positive vs negative) should show:
# Original ≈ Recreated > Base (positive prompts),
# demonstrating successful style recovery.

# %%
# ------------------ SETTINGS ------------------
OUT_ROOT   = Path("./clip_style_eval_outputs")
META_PATH  = OUT_ROOT / "gen_records.json"
SCORED_PATH = OUT_ROOT / "scored_records.json"

REF_DIR = Path("./tattoo_refs")  # put held-out tattoo images here
TOPK = 5

device = "cuda" if torch.cuda.is_available() else "cpu"

def list_images(folder: Path) -> List[Path]:
    exts = {".png", ".jpg", ".jpeg", ".webp", ".bmp"}
    return sorted([p for p in folder.rglob("*") if p.suffix.lower() in exts])

# ------------------ LOAD RECORDS + PATHS ------------------
with open(META_PATH, "r") as f:
    gen_records: List[Dict] = json.load(f)

ref_paths = list_images(REF_DIR)
assert len(ref_paths) > 0, f"No reference images found in {REF_DIR.resolve()}"
gen_paths = [r["path"] for r in gen_records]

print("Generated images:", len(gen_paths))
print("Reference images:", len(ref_paths))

# ------------------ CLIP ------------------
clip_model_id = "openai/clip-vit-large-patch14"
clip_model = CLIPModel.from_pretrained(clip_model_id).to(device).eval()
clip_processor = CLIPProcessor.from_pretrained(clip_model_id)

def load_pil(path: str | Path) -> Image.Image:
    return Image.open(path).convert("RGB")

@torch.inference_mode()
def clip_embed_images(paths, batch_size: int = 16) -> torch.Tensor:
    embs = []
    for i in range(0, len(paths), batch_size):
        batch_paths = paths[i:i+batch_size]
        images = [load_pil(p) for p in batch_paths]
        inputs = clip_processor(images=images, return_tensors="pt").to(device)

        vision_out = clip_model.vision_model(pixel_values=inputs["pixel_values"])
        pooled = vision_out.pooler_output
        feats = clip_model.visual_projection(pooled)

        feats = feats / feats.norm(dim=-1, keepdim=True).clamp(min=1e-12)
        embs.append(feats.detach().float().cpu())
    return torch.cat(embs, dim=0)

def topk_similarity_scores(gen_emb: torch.Tensor, ref_emb: torch.Tensor, k: int = 5) -> np.ndarray:
    k = max(1, min(int(k), ref_emb.shape[0]))
    sim = gen_emb @ ref_emb.T
    topk_vals, _ = torch.topk(sim, k=k, dim=1, largest=True, sorted=False)
    return topk_vals.mean(dim=1).numpy()

# ------------------ EMBED + SCORE ------------------
ref_emb = clip_embed_images(ref_paths, batch_size=16)
gen_emb = clip_embed_images(gen_paths, batch_size=16)

scores = topk_similarity_scores(gen_emb, ref_emb, k=TOPK)
for r, s in zip(gen_records, scores):
    r["clip_topk_mean"] = float(s)

# Save scored records so PCA can load later without recomputing CLIP scores
with open(SCORED_PATH, "w") as f:
    json.dump(gen_records, f, indent=2)

print(f"Saved scored records → {SCORED_PATH.resolve()}")

# ------------------ AGGREGATE SUMMARY ------------------
def mean_std(xs: List[float]) -> Tuple[float, float]:
    xs = np.asarray(xs, dtype=np.float64)
    return float(xs.mean()), float(xs.std(ddof=1) if len(xs) > 1 else 0.0)

def aggregate(records: List[Dict]) -> Dict:
    results = {}
    for model_name in sorted({r["model"] for r in records}):
        rec_m = [r for r in records if r["model"] == model_name]
        results[model_name] = {}
        for key, subset in [
            ("pos", [r for r in rec_m if r["polarity"] == "pos"]),
            ("neg", [r for r in rec_m if r["polarity"] == "neg"]),
            ("overall", rec_m),
        ]:
            vals = [r["clip_topk_mean"] for r in subset]
            mu, sd = mean_std(vals)
            results[model_name][key] = {"mean": mu, "std": sd, "n": len(vals)}
    return results

agg = aggregate(gen_records)

print("\n=== CLIP Style Similarity (top-k mean) ===")
for m in ["base", "original", "recreated"]:
    p = agg[m]["pos"]; n = agg[m]["neg"]; o = agg[m]["overall"]
    print(f"\nModel: {m}")
    print(f"  Positive: mean={p['mean']:.4f} std={p['std']:.4f} n={p['n']}")
    print(f"  Negative: mean={n['mean']:.4f} std={n['std']:.4f} n={n['n']}")
    print(f"  Overall:  mean={o['mean']:.4f} std={o['std']:.4f} n={o['n']}")

# %% [markdown]
# Let:
# - \( g \) = generated image embedding (L2-normalized)
# - \( r_i \) = reference tattoo embeddings (L2-normalized)
#
# Similarity score per image:
#
# $$
# S(g) = \frac{1}{k} \sum_{i \in \text{Top-}k} g^\top r_i
# $$
#
# where Top-k selects the k highest cosine similarities (k = 5).
#
# We then compute:
#
# $$
# \mu_{\text{pos}} = \mathbb{E}[S(g)] \quad \text{over positive prompts}
# $$
# $$
# \mu_{\text{neg}} = \mathbb{E}[S(g)] \quad \text{over negative prompts}
# $$
#
# Style Control Gap:
#
# $$
# \text{Gap} = \mu_{\text{pos}} - \mu_{\text{neg}}
# $$

# %%
import numpy as np
import matplotlib.pyplot as plt

models = ["base", "original", "recreated"]
pos = np.array([agg[m]["pos"]["mean"] for m in models], dtype=float)
neg = np.array([agg[m]["neg"]["mean"] for m in models], dtype=float)
gap = pos - neg

plt.figure(figsize=(8, 5))
ax = plt.gca()
ax.bar(np.arange(len(models)), gap)

ax.set_xticks(np.arange(len(models)))
ax.set_xticklabels(models)
ax.set_ylabel("mean(pos similarity) − mean(neg similarity)")
ax.set_title("Style Control Gap (Higher = Better Style Triggering)")

plt.tight_layout()
plt.show()

for m, g in zip(models, gap):
    print(f"{m}: gap={g:.4f}")

# %% [markdown]
# ## Metric #2 — PCA of CLIP Embeddings (Pos vs Neg)
#
# Loads the generated images listed in `scored_records.json`, computes CLIP image embeddings, then projects embeddings to 2D with PCA and plots model clusters separately for **positive** and **negative** prompts (base vs original vs recreated).
#
# **PCA (formula):** given centered embeddings $$X \in \mathbb{R}^{n \times d}$$PCA finds directions $$W \in \mathbb{R}^{d \times 2}$$ that maximize variance:
# $$
# W=\arg\max_{W^\top W=I}\ \mathrm{Tr}(W^\top X^\top X W)
# $$
# and the 2D projection is:
# $$
# Z = XW \in \mathbb{R}^{n \times 2}
# $$
#
# **What it shows:** whether outputs from the three models form distinct/overlapping clusters in embedding space under positive vs negative prompts (e.g., original ≈ recreated clustering indicates recovered behavior).

# %%
# ------------------ SETTINGS ------------------
OUT_ROOT = Path("./clip_style_eval_outputs")
SCORED_PATH = OUT_ROOT / "scored_records.json"

device = "cuda" if torch.cuda.is_available() else "cpu"

# ------------------ LOAD SCORED RECORDS ------------------
with open(SCORED_PATH, "r") as f:
    gen_records = json.load(f)

gen_paths = [r["path"] for r in gen_records]

# ------------------ CLIP EMBEDDINGS (generated only) ------------------
clip_model_id = "openai/clip-vit-large-patch14"
clip_model = CLIPModel.from_pretrained(clip_model_id).to(device).eval()
clip_processor = CLIPProcessor.from_pretrained(clip_model_id)

def load_pil(path: str | Path) -> Image.Image:
    return Image.open(path).convert("RGB")

@torch.inference_mode()
def clip_embed_images(paths, batch_size: int = 16) -> torch.Tensor:
    embs = []
    for i in range(0, len(paths), batch_size):
        batch_paths = paths[i:i+batch_size]
        images = [load_pil(p) for p in batch_paths]
        inputs = clip_processor(images=images, return_tensors="pt").to(device)

        vision_out = clip_model.vision_model(pixel_values=inputs["pixel_values"])
        pooled = vision_out.pooler_output
        feats = clip_model.visual_projection(pooled)
        feats = feats / feats.norm(dim=-1, keepdim=True).clamp(min=1e-12)
        embs.append(feats.detach().float().cpu())
    return torch.cat(embs, dim=0)

gen_emb = clip_embed_images(gen_paths, batch_size=16)  # [N, D]

# ------------------ PCA PLOTS ------------------
MODELS = ["base", "original", "recreated"]

def plot_pca_split(ax, polarity: str, title: str):
    idx = [i for i, r in enumerate(gen_records) if r["polarity"] == polarity]
    emb = gen_emb[idx].numpy().astype(np.float32)
    labels = [gen_records[i]["model"] for i in idx]

    pca = PCA(n_components=2, random_state=0)
    xy = pca.fit_transform(emb)

    for m in MODELS:
        mask = np.array([lab == m for lab in labels])
        ax.scatter(xy[mask, 0], xy[mask, 1], alpha=0.7, label=m)

    ax.set_title(title)
    ax.set_xlabel(f"PC1 ({pca.explained_variance_ratio_[0]*100:.2f}% var)")
    ax.set_ylabel(f"PC2 ({pca.explained_variance_ratio_[1]*100:.2f}% var)")
    ax.legend(loc="best")

plt.figure(figsize=(14, 6))
ax1 = plt.subplot(1, 2, 1)
plot_pca_split(ax1, "pos", "PCA of CLIP Embeddings (Positive Prompts)")

ax2 = plt.subplot(1, 2, 2)
plot_pca_split(ax2, "neg", "PCA of CLIP Embeddings (Negative Prompts)")

plt.tight_layout()
plt.show()
